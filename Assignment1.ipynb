# %%
#importing necessary libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Dataset Preprocessing and loading of dataset

# %%
df=pd.read_csv(r"C:\Users\sarth\Desktop\Datasets\uber.csv")
df
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [200000 rows x 9 columns]

# %%
#Preprocessing
df=df.drop(['Unnamed: 0','pickup_datetime'],axis=1)

# %%
df
# Out:
#                                   key  fare_amount  pickup_longitude  \
# 0         2015-05-07 19:52:06.0000003          7.5        -73.999817
# 1         2009-07-17 20:04:56.0000002          7.7        -73.994355
# 2        2009-08-24 21:45:00.00000061         12.9        -74.005043
# 3         2009-06-26 08:22:21.0000001          5.3        -73.976124
# 4       2014-08-28 17:47:00.000000188         16.0        -73.925023
# ...                               ...          ...               ...
# 199995   2012-10-28 10:49:00.00000053          3.0        -73.987042
# 199996    2014-03-14 01:09:00.0000008          7.5        -73.984722
# 199997   2009-06-29 00:42:00.00000078         30.9        -73.986017
# 199998    2015-05-20 14:56:25.0000004         14.5        -73.997124
# 199999   2010-05-15 04:08:00.00000076         14.1        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# 1             40.728225         -73.994710         40.750325                1
# 2             40.740770         -73.962565         40.772647                1
# 3             40.790844         -73.965316         40.803349                3
# 4             40.744085         -73.973082         40.761247                5
# ...                 ...                ...               ...              ...
# 199995        40.739367         -73.986525         40.740297                1
# 199996        40.736837         -74.006672         40.739620                1
# 199997        40.756487         -73.858957         40.692588                2
# 199998        40.725452         -73.983215         40.695415                1
# 199999        40.720077         -73.985508         40.768793                1
#
# [200000 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
df.shape
# Out:
# (199999, 7)

# %%
df.size
# Out:
# 1399993

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  199999.000000     199999.000000    199999.000000      199999.000000
# mean       11.359892        -72.527631        39.935881         -72.525292
# std         9.901760         11.437815         7.720558          13.117408
# min       -52.000000      -1340.648410       -74.015515       -3356.666300
# 25%         6.000000        -73.992065        40.734796         -73.991407
# 50%         8.500000        -73.981823        40.752592         -73.980093
# 75%        12.500000        -73.967154        40.767158         -73.963658
# max       499.000000         57.418457      1644.421482        1153.572603
#
#        dropoff_latitude  passenger_count
# count     199999.000000    199999.000000
# mean          39.923890         1.684543
# std            6.794829         1.385995
# min         -881.985513         0.000000
# 25%           40.733823         1.000000
# 50%           40.753042         1.000000
# 75%           40.768001         2.000000
# max          872.697628       208.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199999 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                199999 non-null  object
#  1   fare_amount        199999 non-null  float64
#  2   pickup_longitude   199999 non-null  float64
#  3   pickup_latitude    199999 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    199999 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 12.2+ MB

# %%
df.drop(['key'],axis=1)
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               7.5        -73.999817        40.738354         -73.999512
# 1               7.7        -73.994355        40.728225         -73.994710
# 2              12.9        -74.005043        40.740770         -73.962565
# 3               5.3        -73.976124        40.790844         -73.965316
# 4              16.0        -73.925023        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 199995          3.0        -73.987042        40.739367         -73.986525
# 199996          7.5        -73.984722        40.736837         -74.006672
# 199997         30.9        -73.986017        40.756487         -73.858957
# 199998         14.5        -73.997124        40.725452         -73.983215
# 199999         14.1        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count
# 0              40.723217                1
# 1              40.750325                1
# 2              40.772647                1
# 3              40.803349                3
# 4              40.761247                5
# ...                  ...              ...
# 199995         40.740297                1
# 199996         40.739620                1
# 199997         40.692588                2
# 199998         40.695415                1
# 199999         40.768793                1
#
# [199999 rows x 6 columns]

# %%
#Identify Outliers

# %%
def detect_outliers(df,feature):
    q1=df[feature].quantile(0.25)
    q3=df[feature].quantile(0.75)
    iqr=q3-q1
    lower_limit=q1-1.5*iqr
    upper_limit=q3+1.5*iqr
    return df[(df[feature]<lower_limit)|(df[feature]>upper_limit)]

# %%
detect_outliers(df,'fare_amount')
# Out:
#                                   key  fare_amount  pickup_longitude  \
# 6         2014-10-12 07:04:00.0000002        24.50        -73.961447
# 30       2011-05-21 09:00:00.00000031        25.70        -73.944815
# 34      2014-06-04 06:49:00.000000102        39.50        -73.788080
# 39      2014-02-13 17:57:00.000000102        29.00        -73.992600
# 48        2013-01-03 22:24:41.0000002        56.80        -73.993498
# ...                               ...          ...               ...
# 199976  2011-10-18 23:53:00.000000145        49.70        -73.978225
# 199977    2012-11-20 21:04:30.0000001        43.50        -73.996671
# 199982    2014-08-06 11:06:06.0000001        57.33        -73.969204
# 199985    2015-04-18 15:16:06.0000005        24.00        -74.005089
# 199997   2009-06-29 00:42:00.00000078        30.90        -73.986017
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 6             40.693965         -73.871195         40.774297                5
# 30            40.834367         -73.989332         40.721920                4
# 34            40.642187         -73.865042         40.725997                4
# 39            40.753172         -73.908508         40.816192                1
# 48            40.764686         -73.993498         40.764686                1
# ...                 ...                ...               ...              ...
# 199976        40.783318         -73.700963         40.705852                1
# 199977        40.737483         -73.867758         40.897563                1
# 199982        40.754771         -73.790351         40.643802                1
# 199985        40.737301         -73.945290         40.774162                5
# 199997        40.756487         -73.858957         40.692588                2
#
# [17166 rows x 7 columns]

# %%
#Remove Outliers

# %%
def remove_outliers(df,feature):
    q1=df[feature].quantile(0.25)
    q3=df[feature].quantile(0.75)
    iqr=q3-q1
    lower_limit=q1-1.5*iqr
    upper_limit=q3+1.5*iqr
    return df[(df[feature]>lower_limit)|(df[feature]<upper_limit)]

# %%
df=remove_outliers(df,'fare_amount')

# %%
df
# Out:
#                                   key  fare_amount  pickup_longitude  \
# 0         2015-05-07 19:52:06.0000003          7.5        -73.999817
# 1         2009-07-17 20:04:56.0000002          7.7        -73.994355
# 2        2009-08-24 21:45:00.00000061         12.9        -74.005043
# 3         2009-06-26 08:22:21.0000001          5.3        -73.976124
# 4       2014-08-28 17:47:00.000000188         16.0        -73.925023
# ...                               ...          ...               ...
# 199995   2012-10-28 10:49:00.00000053          3.0        -73.987042
# 199996    2014-03-14 01:09:00.0000008          7.5        -73.984722
# 199997   2009-06-29 00:42:00.00000078         30.9        -73.986017
# 199998    2015-05-20 14:56:25.0000004         14.5        -73.997124
# 199999   2010-05-15 04:08:00.00000076         14.1        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# 0             40.738354         -73.999512         40.723217                1
# 1             40.728225         -73.994710         40.750325                1
# 2             40.740770         -73.962565         40.772647                1
# 3             40.790844         -73.965316         40.803349                3
# 4             40.744085         -73.973082         40.761247                5
# ...                 ...                ...               ...              ...
# 199995        40.739367         -73.986525         40.740297                1
# 199996        40.736837         -74.006672         40.739620                1
# 199997        40.756487         -73.858957         40.692588                2
# 199998        40.725452         -73.983215         40.695415                1
# 199999        40.720077         -73.985508         40.768793                1
#
# [199999 rows x 7 columns]

# %%
#Identifying outliers using box plot

# %%
plt.figure(figsize=(12,8))
sns.boxplot(x='fare_amount',data=df)
plt.show()

# %%
#Check for correlation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199999 entries, 0 to 199999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   key                199999 non-null  object
#  1   fare_amount        199999 non-null  float64
#  2   pickup_longitude   199999 non-null  float64
#  3   pickup_latitude    199999 non-null  float64
#  4   dropoff_longitude  199999 non-null  float64
#  5   dropoff_latitude   199999 non-null  float64
#  6   passenger_count    199999 non-null  int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 12.2+ MB

# %%
df.drop(['key'],axis=1,inplace=True)

# %%
df
# Out:
#         fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0               7.5        -73.999817        40.738354         -73.999512
# 1               7.7        -73.994355        40.728225         -73.994710
# 2              12.9        -74.005043        40.740770         -73.962565
# 3               5.3        -73.976124        40.790844         -73.965316
# 4              16.0        -73.925023        40.744085         -73.973082
# ...             ...               ...              ...                ...
# 199995          3.0        -73.987042        40.739367         -73.986525
# 199996          7.5        -73.984722        40.736837         -74.006672
# 199997         30.9        -73.986017        40.756487         -73.858957
# 199998         14.5        -73.997124        40.725452         -73.983215
# 199999         14.1        -73.984395        40.720077         -73.985508
#
#         dropoff_latitude  passenger_count
# 0              40.723217                1
# 1              40.750325                1
# 2              40.772647                1
# 3              40.803349                3
# 4              40.761247                5
# ...                  ...              ...
# 199995         40.740297                1
# 199996         40.739620                1
# 199997         40.692588                2
# 199998         40.695415                1
# 199999         40.768793                1
#
# [199999 rows x 6 columns]

# %%
corr=df.corr()

# %%
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
#Implement Linear Regression

# %%
from sklearn.model_selection import train_test_split

# %%
#Selection of dependent and independent variable
X=df.drop(['fare_amount'],axis=1)
Y=df.fare_amount

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
#Evaluation

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
RMSE=np.sqrt(mean_squared_error(y_test,y_pred))

# %%
print("RMSE: ",RMSE)
# Out:
# RMSE:  9.858690988363255

# %%
R2=r2_score(y_test,y_pred)
print("R2: ",R2)
# Out:
# R2:  0.0003249026036721281

# %%
#Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model1=RandomForestRegressor()

# %%
model1.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model1.predict(x_test)

# %%
#Evaluation

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE: ",RMSE)
# Out:
# RMSE:  4.681959173029029

# %%
R2=r2_score(y_test,y_pred)
print("R2: ",R2)
# Out:
# R2:  0.7745368295456404
